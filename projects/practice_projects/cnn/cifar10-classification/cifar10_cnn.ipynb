# %% [markdown]
# ## Convolutional Neural Networks
#
# ---
#
# In this notebook, we train a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# /home/yannis/anaconda3/envs/working/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualize the First 24 Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Break Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compile the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Train the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=100,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
#  - 13s - loss: 1.5915 - acc: 0.4274 - val_loss: 1.3225 - val_acc: 0.5282
#
# Epoch 00001: val_loss improved from inf to 1.32253, saving model to model.weights.best.hdf5
# Epoch 2/100
#  - 11s - loss: 1.2594 - acc: 0.5532 - val_loss: 1.0577 - val_acc: 0.6186
#
# Epoch 00002: val_loss improved from 1.32253 to 1.05767, saving model to model.weights.best.hdf5
# Epoch 3/100
#  - 11s - loss: 1.1296 - acc: 0.6013 - val_loss: 1.0287 - val_acc: 0.6294
#
# Epoch 00003: val_loss improved from 1.05767 to 1.02873, saving model to model.weights.best.hdf5
# Epoch 4/100
#  - 12s - loss: 1.0551 - acc: 0.6282 - val_loss: 0.9703 - val_acc: 0.6614
#
# Epoch 00004: val_loss improved from 1.02873 to 0.97029, saving model to model.weights.best.hdf5
# Epoch 5/100
#  - 11s - loss: 1.0119 - acc: 0.6457 - val_loss: 0.9520 - val_acc: 0.6550
#
# Epoch 00005: val_loss improved from 0.97029 to 0.95203, saving model to model.weights.best.hdf5
# Epoch 6/100
#  - 11s - loss: 0.9874 - acc: 0.6570 - val_loss: 0.9253 - val_acc: 0.6780
#
# Epoch 00006: val_loss improved from 0.95203 to 0.92530, saving model to model.weights.best.hdf5
# Epoch 7/100
#  - 12s - loss: 0.9703 - acc: 0.6680 - val_loss: 1.0229 - val_acc: 0.6682
#
# Epoch 00007: val_loss did not improve
# Epoch 8/100
#  - 11s - loss: 0.9624 - acc: 0.6720 - val_loss: 1.0876 - val_acc: 0.6496
#
# Epoch 00008: val_loss did not improve
# Epoch 9/100
#  - 12s - loss: 0.9644 - acc: 0.6711 - val_loss: 0.8915 - val_acc: 0.6984
#
# Epoch 00009: val_loss improved from 0.92530 to 0.89150, saving model to model.weights.best.hdf5
# Epoch 10/100
#  - 11s - loss: 0.9730 - acc: 0.6733 - val_loss: 1.1047 - val_acc: 0.6570
#
# Epoch 00010: val_loss did not improve
# Epoch 11/100
#  - 11s - loss: 0.9800 - acc: 0.6708 - val_loss: 0.9089 - val_acc: 0.7004
#
# Epoch 00011: val_loss did not improve
# Epoch 12/100
#  - 11s - loss: 0.9883 - acc: 0.6708 - val_loss: 1.0288 - val_acc: 0.6852
#
# Epoch 00012: val_loss did not improve
# Epoch 13/100
#  - 12s - loss: 1.0034 - acc: 0.6674 - val_loss: 1.7699 - val_acc: 0.5144
#
# Epoch 00013: val_loss did not improve
# Epoch 14/100
#  - 12s - loss: 1.0200 - acc: 0.6635 - val_loss: 0.9530 - val_acc: 0.6816
#
# Epoch 00014: val_loss did not improve
# Epoch 15/100
#  - 13s - loss: 1.0311 - acc: 0.6590 - val_loss: 1.0059 - val_acc: 0.6578
#
# Epoch 00015: val_loss did not improve
# Epoch 16/100
#  - 13s - loss: 1.0543 - acc: 0.6558 - val_loss: 0.9210 - val_acc: 0.7054
#
# Epoch 00016: val_loss did not improve
# Epoch 17/100
#  - 12s - loss: 1.0660 - acc: 0.6509 - val_loss: 1.0392 - val_acc: 0.6578
#
# Epoch 00017: val_loss did not improve
# Epoch 18/100
#  - 12s - loss: 1.0999 - acc: 0.6398 - val_loss: 1.3431 - val_acc: 0.5264
#
# Epoch 00018: val_loss did not improve
# Epoch 19/100
#  - 13s - loss: 1.1151 - acc: 0.6368 - val_loss: 1.0458 - val_acc: 0.6456
#
# Epoch 00019: val_loss did not improve
# Epoch 20/100
#  - 12s - loss: 1.1429 - acc: 0.6278 - val_loss: 1.0977 - val_acc: 0.6806
#
# Epoch 00020: val_loss did not improve
# Epoch 21/100
#  - 12s - loss: 1.1682 - acc: 0.6219 - val_loss: 1.0964 - val_acc: 0.6430
#
# Epoch 00021: val_loss did not improve
# Epoch 22/100
#  - 12s - loss: 1.1924 - acc: 0.6141 - val_loss: 1.1212 - val_acc: 0.6316
#
# Epoch 00022: val_loss did not improve
# Epoch 23/100
#  - 12s - loss: 1.1984 - acc: 0.6090 - val_loss: 1.4410 - val_acc: 0.5040
#
# Epoch 00023: val_loss did not improve
# Epoch 24/100
#  - 12s - loss: 1.2272 - acc: 0.6012 - val_loss: 1.1274 - val_acc: 0.6228
#
# Epoch 00024: val_loss did not improve
# Epoch 25/100
#  - 11s - loss: 1.2347 - acc: 0.5988 - val_loss: 1.1733 - val_acc: 0.6020
#
# Epoch 00025: val_loss did not improve
# Epoch 26/100
#  - 12s - loss: 1.2542 - acc: 0.5912 - val_loss: 1.6889 - val_acc: 0.6000
#
# Epoch 00026: val_loss did not improve
# Epoch 27/100
#  - 12s - loss: 1.2753 - acc: 0.5866 - val_loss: 1.5776 - val_acc: 0.5718
#
# Epoch 00027: val_loss did not improve
# Epoch 28/100
#  - 12s - loss: 1.2955 - acc: 0.5790 - val_loss: 1.0871 - val_acc: 0.6478
#
# Epoch 00028: val_loss did not improve
# Epoch 29/100
#  - 13s - loss: 1.3063 - acc: 0.5758 - val_loss: 1.1360 - val_acc: 0.6298
#
# Epoch 00029: val_loss did not improve
# Epoch 30/100
#  - 12s - loss: 1.3263 - acc: 0.5706 - val_loss: 1.6188 - val_acc: 0.4898
#
# Epoch 00030: val_loss did not improve
# Epoch 31/100
#  - 12s - loss: 1.3376 - acc: 0.5600 - val_loss: 1.5310 - val_acc: 0.5074
#
# Epoch 00031: val_loss did not improve
# Epoch 32/100
#  - 12s - loss: 1.3310 - acc: 0.5594 - val_loss: 1.9602 - val_acc: 0.4786
#
# Epoch 00032: val_loss did not improve
# Epoch 33/100
#  - 12s - loss: 1.3574 - acc: 0.5531 - val_loss: 1.1974 - val_acc: 0.6130
#
# Epoch 00033: val_loss did not improve
# Epoch 34/100
#  - 12s - loss: 1.3671 - acc: 0.5512 - val_loss: 1.5244 - val_acc: 0.5320
#
# Epoch 00034: val_loss did not improve
# Epoch 35/100
#  - 11s - loss: 1.3823 - acc: 0.5436 - val_loss: 2.2423 - val_acc: 0.5678
#
# Epoch 00035: val_loss did not improve
# Epoch 36/100
#  - 12s - loss: 1.3953 - acc: 0.5416 - val_loss: 1.4986 - val_acc: 0.5486
#
# Epoch 00036: val_loss did not improve
# Epoch 37/100
#  - 12s - loss: 1.4019 - acc: 0.5399 - val_loss: 1.2433 - val_acc: 0.6088
#
# Epoch 00037: val_loss did not improve
# Epoch 38/100
#  - 12s - loss: 1.4136 - acc: 0.5324 - val_loss: 1.4782 - val_acc: 0.4870
#
# Epoch 00038: val_loss did not improve
# Epoch 39/100
#  - 11s - loss: 1.4323 - acc: 0.5240 - val_loss: 1.1661 - val_acc: 0.6014
#
# Epoch 00039: val_loss did not improve
# Epoch 40/100
#  - 12s - loss: 1.4521 - acc: 0.5192 - val_loss: 1.2947 - val_acc: 0.5476
#
# Epoch 00040: val_loss did not improve
# Epoch 41/100
#  - 12s - loss: 1.4734 - acc: 0.5164 - val_loss: 1.5666 - val_acc: 0.4340
#
# Epoch 00041: val_loss did not improve
# Epoch 42/100
#  - 11s - loss: 1.4764 - acc: 0.5095 - val_loss: 1.3222 - val_acc: 0.5424
#
# Epoch 00042: val_loss did not improve
# Epoch 43/100
#  - 12s - loss: 1.5133 - acc: 0.4992 - val_loss: 1.6143 - val_acc: 0.5144
#
# Epoch 00043: val_loss did not improve
# Epoch 44/100
#  - 11s - loss: 1.5236 - acc: 0.4922 - val_loss: 1.8372 - val_acc: 0.4464
#
# Epoch 00044: val_loss did not improve
# Epoch 45/100
#  - 11s - loss: 1.5374 - acc: 0.4876 - val_loss: 1.8302 - val_acc: 0.4694
#
# Epoch 00045: val_loss did not improve
# Epoch 46/100
#  - 12s - loss: 1.5541 - acc: 0.4830 - val_loss: 1.3384 - val_acc: 0.5468
#
# Epoch 00046: val_loss did not improve
# Epoch 47/100
#  - 11s - loss: 1.5744 - acc: 0.4759 - val_loss: 1.2762 - val_acc: 0.5724
#
# Epoch 00047: val_loss did not improve
# Epoch 48/100
#  - 12s - loss: 1.5582 - acc: 0.4744 - val_loss: 1.5856 - val_acc: 0.4930
#
# Epoch 00048: val_loss did not improve
# Epoch 49/100
#  - 12s - loss: 1.5888 - acc: 0.4686 - val_loss: 1.5649 - val_acc: 0.5094
#
# Epoch 00049: val_loss did not improve
# Epoch 50/100
#  - 12s - loss: 1.5911 - acc: 0.4659 - val_loss: 1.6690 - val_acc: 0.4806
#
# Epoch 00050: val_loss did not improve
# Epoch 51/100
#  - 12s - loss: 1.6104 - acc: 0.4600 - val_loss: 1.5691 - val_acc: 0.4142
#
# Epoch 00051: val_loss did not improve
# Epoch 52/100
#  - 11s - loss: 1.6245 - acc: 0.4586 - val_loss: 1.3902 - val_acc: 0.5266
#
# Epoch 00052: val_loss did not improve
# Epoch 53/100
#  - 12s - loss: 1.6265 - acc: 0.4539 - val_loss: 1.4360 - val_acc: 0.5130
#
# Epoch 00053: val_loss did not improve
# Epoch 54/100
#  - 12s - loss: 1.6252 - acc: 0.4505 - val_loss: 1.3507 - val_acc: 0.5458
#
# Epoch 00054: val_loss did not improve
# Epoch 55/100
#  - 12s - loss: 1.6264 - acc: 0.4474 - val_loss: 1.8795 - val_acc: 0.3762
#
# Epoch 00055: val_loss did not improve
# Epoch 56/100
#  - 12s - loss: 1.6241 - acc: 0.4468 - val_loss: 1.6354 - val_acc: 0.4180
#
# Epoch 00056: val_loss did not improve
# Epoch 57/100
#  - 12s - loss: 1.6463 - acc: 0.4450 - val_loss: 1.6837 - val_acc: 0.4310
#
# Epoch 00057: val_loss did not improve
# Epoch 58/100
#  - 11s - loss: 1.6409 - acc: 0.4457 - val_loss: 1.4241 - val_acc: 0.5452
#
# Epoch 00058: val_loss did not improve
# Epoch 59/100
#  - 12s - loss: 1.6494 - acc: 0.4412 - val_loss: 1.5855 - val_acc: 0.5046
#
# Epoch 00059: val_loss did not improve
# Epoch 60/100
#  - 13s - loss: 1.6461 - acc: 0.4416 - val_loss: 1.3787 - val_acc: 0.5410
#
# Epoch 00060: val_loss did not improve
# Epoch 61/100
#  - 11s - loss: 1.6631 - acc: 0.4405 - val_loss: 1.3730 - val_acc: 0.4996
#
# Epoch 00061: val_loss did not improve
# Epoch 62/100
#  - 11s - loss: 1.6429 - acc: 0.4401 - val_loss: 1.4517 - val_acc: 0.4778
#
# Epoch 00062: val_loss did not improve
# Epoch 63/100
#  - 11s - loss: 1.6471 - acc: 0.4422 - val_loss: 1.4072 - val_acc: 0.5128
#
# Epoch 00063: val_loss did not improve
# Epoch 64/100
#  - 11s - loss: 1.6465 - acc: 0.4444 - val_loss: 1.3855 - val_acc: 0.5054
#
# Epoch 00064: val_loss did not improve
# Epoch 65/100
#  - 11s - loss: 1.6525 - acc: 0.4420 - val_loss: 1.5277 - val_acc: 0.4320
#
# Epoch 00065: val_loss did not improve
# Epoch 66/100
#  - 11s - loss: 1.6549 - acc: 0.4418 - val_loss: 1.7680 - val_acc: 0.4910
#
# Epoch 00066: val_loss did not improve
# Epoch 67/100
#  - 11s - loss: 1.6612 - acc: 0.4345 - val_loss: 2.8022 - val_acc: 0.3344
#
# Epoch 00067: val_loss did not improve
# Epoch 68/100
#  - 12s - loss: 1.6722 - acc: 0.4326 - val_loss: 1.5071 - val_acc: 0.4626
#
# Epoch 00068: val_loss did not improve
# Epoch 69/100
#  - 11s - loss: 1.6742 - acc: 0.4336 - val_loss: 2.2573 - val_acc: 0.3192
#
# Epoch 00069: val_loss did not improve
# Epoch 70/100
#  - 11s - loss: 1.6898 - acc: 0.4255 - val_loss: 2.0061 - val_acc: 0.3528
#
# Epoch 00070: val_loss did not improve
# Epoch 71/100
#  - 11s - loss: 1.6953 - acc: 0.4213 - val_loss: 1.4872 - val_acc: 0.4502
#
# Epoch 00071: val_loss did not improve
# Epoch 72/100
#  - 12s - loss: 1.7007 - acc: 0.4194 - val_loss: 1.7363 - val_acc: 0.4646
#
# Epoch 00072: val_loss did not improve
# Epoch 73/100
#  - 11s - loss: 1.6993 - acc: 0.4168 - val_loss: 1.4419 - val_acc: 0.5124
#
# Epoch 00073: val_loss did not improve
# Epoch 74/100
#  - 12s - loss: 1.7018 - acc: 0.4167 - val_loss: 1.7832 - val_acc: 0.3690
#
# Epoch 00074: val_loss did not improve
# Epoch 75/100
#  - 11s - loss: 1.7100 - acc: 0.4174 - val_loss: 1.6434 - val_acc: 0.4004
#
# Epoch 00075: val_loss did not improve
# Epoch 76/100
#  - 12s - loss: 1.7026 - acc: 0.4156 - val_loss: 1.4462 - val_acc: 0.4798
#
# Epoch 00076: val_loss did not improve
# Epoch 77/100
#  - 12s - loss: 1.7251 - acc: 0.4091 - val_loss: 1.5470 - val_acc: 0.4896
#
# Epoch 00077: val_loss did not improve
# Epoch 78/100
#  - 11s - loss: 1.7174 - acc: 0.4133 - val_loss: 1.6382 - val_acc: 0.4108
#
# Epoch 00078: val_loss did not improve
# Epoch 79/100
#  - 12s - loss: 1.7357 - acc: 0.4019 - val_loss: 1.7167 - val_acc: 0.4820
#
# Epoch 00079: val_loss did not improve
# Epoch 80/100
#  - 12s - loss: 1.7453 - acc: 0.3994 - val_loss: 1.4071 - val_acc: 0.4912
#
# Epoch 00080: val_loss did not improve
# Epoch 81/100
#  - 12s - loss: 1.7537 - acc: 0.4031 - val_loss: 1.5446 - val_acc: 0.4538
#
# Epoch 00081: val_loss did not improve
# Epoch 82/100
#  - 12s - loss: 1.7754 - acc: 0.3926 - val_loss: 1.4918 - val_acc: 0.4700
#
# Epoch 00082: val_loss did not improve
# Epoch 83/100
#  - 12s - loss: 1.7643 - acc: 0.3890 - val_loss: 1.5125 - val_acc: 0.4122
#
# Epoch 00083: val_loss did not improve
# Epoch 84/100
#  - 12s - loss: 1.7767 - acc: 0.3892 - val_loss: 1.7733 - val_acc: 0.3714
#
# Epoch 00084: val_loss did not improve
# Epoch 85/100
#  - 12s - loss: 1.7559 - acc: 0.3868 - val_loss: 2.9448 - val_acc: 0.3020
#
# Epoch 00085: val_loss did not improve
# Epoch 86/100
#  - 11s - loss: 1.7561 - acc: 0.3910 - val_loss: 1.4801 - val_acc: 0.4836
#
# Epoch 00086: val_loss did not improve
# Epoch 87/100
#  - 11s - loss: 1.7591 - acc: 0.3876 - val_loss: 3.9944 - val_acc: 0.2954
#
# Epoch 00087: val_loss did not improve
# Epoch 88/100
#  - 11s - loss: 1.7888 - acc: 0.3869 - val_loss: 1.7086 - val_acc: 0.4488
#
# Epoch 00088: val_loss did not improve
# Epoch 89/100
#  - 12s - loss: 1.7865 - acc: 0.3848 - val_loss: 1.6122 - val_acc: 0.4048
#
# Epoch 00089: val_loss did not improve
# Epoch 90/100
#  - 12s - loss: 1.7986 - acc: 0.3781 - val_loss: 1.5694 - val_acc: 0.4392
#
# Epoch 00090: val_loss did not improve
# Epoch 91/100
#  - 12s - loss: 1.7936 - acc: 0.3738 - val_loss: 1.8512 - val_acc: 0.3860
#
# Epoch 00091: val_loss did not improve
# Epoch 92/100
#  - 12s - loss: 1.8094 - acc: 0.3707 - val_loss: 1.6979 - val_acc: 0.3758
#
# Epoch 00092: val_loss did not improve
# Epoch 93/100
#  - 12s - loss: 1.8035 - acc: 0.3723 - val_loss: 1.5140 - val_acc: 0.4498
#
# Epoch 00093: val_loss did not improve
# Epoch 94/100
#  - 12s - loss: 1.8054 - acc: 0.3709 - val_loss: 2.6950 - val_acc: 0.3356
#
# Epoch 00094: val_loss did not improve
# Epoch 95/100
#  - 12s - loss: 1.8232 - acc: 0.3655 - val_loss: 1.5798 - val_acc: 0.4378
#
# Epoch 00095: val_loss did not improve
# Epoch 96/100
#  - 14s - loss: 1.8055 - acc: 0.3663 - val_loss: 1.6491 - val_acc: 0.4046
#
# Epoch 00096: val_loss did not improve
# Epoch 97/100
#  - 12s - loss: 1.8217 - acc: 0.3640 - val_loss: 1.4942 - val_acc: 0.4474
#
# Epoch 00097: val_loss did not improve
# Epoch 98/100
#  - 11s - loss: 1.8438 - acc: 0.3559 - val_loss: 1.4908 - val_acc: 0.4652
#
# Epoch 00098: val_loss did not improve
# Epoch 99/100
#  - 12s - loss: 1.8391 - acc: 0.3567 - val_loss: 1.5369 - val_acc: 0.4360
#
# Epoch 00099: val_loss did not improve
# Epoch 100/100
#  - 12s - loss: 1.8493 - acc: 0.3464 - val_loss: 2.5717 - val_acc: 0.3384
#
# Epoch 00100: val_loss did not improve

# %% [markdown]
# ### 8. Load the Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculate Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.6918

# %% [markdown]
# ### 10. Visualize Some Predictions
#
# This may give you some insight into why the network is misclassifying certain objects.

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(18, 6), sharey=False)

ax1.plot(hist.model.model.history.history['acc'])
ax1.plot(hist.model.model.history.history['val_acc'])
ax1.set_title('Model Accuracy')
ax1.set_ylabel('Accuracy')
ax1.set_xlabel('Epoch')
ax1.legend(['Train', 'Validate'], loc='upper left')

ax2.plot(hist.model.model.history.history['loss'])
ax2.plot(hist.model.model.history.history['val_loss'])
ax2.set_title('Model Loss')
ax2.set_ylabel('Loss')
ax2.set_xlabel('Epoch')
ax2.legend(['Train', 'Validate'], loc='upper right')

plt.show()
